# %% [markdown]
# <a href="https://colab.research.google.com/github/David012345678/BIGMAN/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
david = pd.read_csv('/content/DATASET.csv')
print("Shape of the dataset:", david.shape)
david.head(10)
# Out:
# Shape of the dataset: (69, 8)
#    S.no Instagram name               Name Subscribers  CANDIDATE 1 LIKES  \
# 0     1      cristiano  Cristiano Ronaldo      477.9M                  1
# 1     2    kyliejenner            Kylie 🤍      368.1M                  1
# 2     3   arianagrande      Ariana Grande      329.6M                  0
# 3     4       leomessi          Leo Messi      358.6M                  1
# 4     5        zendaya            Zendaya      151.1M                  1
# 5     6    selenagomez       Selena Gomez      344.2M                  1
# 6     7    taylorswift       Taylor Swift      223.5M                  1
# 7     8            thv                  V       50.8M                  1
# 8     9    virat.kohli        Virat Kohli      212.6M                  1
# 9    10        beyonce           Beyoncé      274.1M                  1
#
#    CANDIDATE 2 LIKE  CANDIDATE 1 MENTION  CANDIDATE 2 MENTION
# 0                 1                    0                   11
# ...

# %%
import pandas as pd
david = pd.read_csv('/content/DATASET.csv')
data=david.loc[:,['CANDIDATE 1 LIKES','CANDIDATE 2 LIKE','CANDIDATE 1 MENTION','CANDIDATE 2 MENTION']]
data.head(10)
# Out:
#    CANDIDATE 1 LIKES  CANDIDATE 2 LIKE  CANDIDATE 1 MENTION  \
# 0                  1                 1                    0
# 1                  1                 0                    0
# 2                  0                 1                   87
# 3                  1                 1                   79
# 4                  1                 0                    0
# 5                  1                 1                    0
# 6                  1                 1                  207
# 7                  1                 1                    0
# 8                  1                 0                   91
# 9                  1                 1                   30
#
#    CANDIDATE 2 MENTION
# 0                   11
# 1                    1
# 2                    0
# 3                   12
# 4                    1
# 5                    0
# 6                    2
# 7                    8
# 8                   80
# 9                   64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
david = pd.read_csv('/content/DATASET.csv')
x = pd.DataFrame(david['CANDIDATE 1 LIKES'])
y = pd.DataFrame(david['CANDIDATE 2 LIKE'])
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# <ipython-input-21-7a3cce87d1fb>:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# RandomForestClassifier(random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[0.65      ],
#        [0.77142857],
#        [0.65      ],
#        [0.77142857],
#        [0.77142857],
#        [0.77142857],
#        [0.65      ],
#        [0.77142857],
#        [0.77142857],
#        [0.65      ],
#        [0.65      ],
#        [0.77142857],
#        [0.77142857],
#        [0.65      ]])

# %%
y_test.head(10)
# Out:
#     CANDIDATE 2 LIKE
# 63                 0
# 31                 0
# 26                 0
# 36                 1
# 65                 0
# 47                 0
# 35                 0
# 56                 0
# 49                 1
# 2                  1

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.2857142857142857

# %%
import joblib
import pickle
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
joblib.dump(model, 'voting_predictive_model.pkl')
with open('voting predictive model.pkl', 'wb') as file:
 pickle.dump(model, file)
